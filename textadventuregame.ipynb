# %% [markdown]
# ## A1: Text Adventure Game Development

# %% [markdown]
# ### <span style="color:red"> *The hunger games*</span>

# %% [markdown]
# -Aminder Pal Kaur

# %% [markdown]
# *For getting to know the game better  follow the link to read about the movie , its plot and its characters* https://en.wikipedia.org/wiki/The_Hunger_Games_(film)

# %%
#This is imported so we can use the sleep function in our code
import time
#This is the first part where you have entered
def scene_1():
    #description of the story 
    """Docstring 
    The game is based on the Movie The hunger Games . The movie was adopted 
    from Suzannes collins 2008 novel which goes by the same name  .
    
    This game has Five scenes each scene being an important part of the movie.
    The first scene give us the introduction .
    The second scene gives the lottery scene from where actually the story begins
    The third scene tell us what happen when katanis goes to the capitol
    Fourth scene is the actual fight scene.
    Fifth scene decides the winner or looser based on users choics
    
    
    Bugs: If you don’t enter proper hint in the scene 1 and scene 5 you have to start from the beginning .
    
    
     
    """
    print("Welcome to The Hunger Games")
    
    #this print statement will display the emoji for making it make beautiful 
    print("\U0001F3F9" * 5)
    #introduction of the new world and what is happening 
    print("""You live in a world where most of the part of the earth is submerged under water ,
     the only habitable place in the world is North America .It has been divided 
    into 12 Districts and each year an event is organised by the dictator in the Capitol of the country named 
    as The Hunger Games . It is done as a punishmenmt of the roits which happened a few years back . 
    For this game the contestant that are choosen are of age between 12 to 16 and they are called tributes 
    and from each district two person are choose one of female and male .They are choosen by a 
    lottery system .""")
    time.sleep(1)
    print("Let the Game Begin")
    count =4
    while count>0:
        count-=1
        print(f"""{count}""")
        time.sleep(1)
    
    
    
    #knowing the name of the user that is playing the game
    name=input(prompt ="What is your name : \n")
    print(f"""Welcome {name} , here in the new  world you will be known as {name} Everdeen . \n """)       
    time.sleep(1)
    
    #condition = True
    #while(condition):
        #attempt = 3
        #if attempt == 0:
           # attempt-=1
            #fail()
    # from here we want to know from the user whether they want to start the game or not
    ans = input(prompt="Do you want to start the game . Hint : Type Yes or No \n" )
    ans = ans.casefold()
    
    #the all possible outcomes that a user can input based on the hint 
    if  'yes' in ans or 'Yes' in ans or 'Y' in ans or 'y' in ans:
        print("Let the story enfold")
        scene_2()
            #condition = False
    elif 'No' in ans or 'no' in ans or 'n' in ans or 'N' in ans:
        print("You need courage to start ")
        print("\U0001F4AA")
        fail()
                #condition = False
            
     # if  the person playin the game did not give us the hint required they will go back to the ans    
    else:
        print("Follow the hint ")
        scene_1()
          
              

#This is the 2 part where you actually start playing the gamne         
def scene_2():
    #the below print statement is used to divide the scenes
    print("=========================================================")
    #describes the story and what is going on
    print("""Today  two tributes are going to be selected .  
     Now you must hurry for the ceremony  .You and your sister go and the name is announced for the 
    female  tribute and its .........................
     """)
    input(prompt="do you want to know the name . press enter ")

    print("Its your sister Primrose Everdeen .You want to save your her what you must do")
    print("\U0001F614")
        #time.sleep() is used to make a pause so that the user can have time to read the scene 
    time.sleep(1)
        #volun variable describes  input  
    volun = input(prompt="Do you want to  volunteer in place of your sister. Hint: type yes or no \n")
    print("\U0001F644")
    volun=volun.casefold()
        #if statement for moving forward to scene from the input if its yes from input we move forward to scene_3
    if 'yes' in volun or 'YES' in volun or 'y'in volun or 'Y' in volun :
        print("You go to the stage and have saved your sister")
        print("\U0001F62A")
        
        scene_3()
        #if the input is no we loose the game hence move to the fail() fuction
    elif 'no'in volun or 'NO' in volun or 'n' in volun or 'N' in volun:
        print("your sister gets selected and she enters the game as tribute and dies . You mourn her death ")
        print("\U0001F62D "* 5)
        fail()
    else:
        #if none of the input answers match this statement will work and we move back to the scene_2 that is it will replay 
        print("You did not write correctly . Please follow the hint ")
        scene_2()
    
    
#    
def scene_3():
    # this print statement is used to divide the scenes 
    print("================================================================")
    #description of what is happening in the scenes 
    print("""You go to the Capitol , you are accompanied by  the other 
          tribute ,  Peete , your mentor Haymitch and Chaperone Effie TRinket . 
          You reach the capitol . Now  you get to meet other team members and choose 
          your weapon """)
    #adding pause in our code 
    time.sleep(1)
    #wea_lst=['bow arrow','bow and arrow','Bow','Bow and Arrow','BOW ARROW','BOW AND ARROW ','ARROW','Axe','axe','AXE']
    bow_lst=['bow arrow','bow and arrow','Bow','Bow and Arrow','BOW ARROW','BOW AND ARROW ','ARROW','bow','arrow']
    axe_lst=['Axe','axe','AXE']
   # choosing the weapon for showoffing your skills 
    wea = input(prompt="What weapon should I choose  bow arrow or axe \n ")
    wea = wea.casefold()
    #this statement will work if bow and arrow is choosen and we move forward to scene_4
    #for   wea in wea_lst:
    if  wea in bow_lst:
        print("""Its a great choice and while showcasing your skills you shot
              your arrow through the open window to the sponsers""")
        scene_4()
    
    # this statement will work if axe is choosen and we move forward to scene_4
    elif  wea in axe_lst :
        print("Its a good choice ")
        scene_4()
    
    # this statement will work when none of the hint is choosen and we go back to the starting of scene_3
    else:
        print("Please choose again from the two hints ")
        scene_3()
            
              
    
                
 # thius is the 4 scene that is defined    
def scene_4():
              #for beautifing our code
    print("======================================================================")
              #description of the scene
    print(" You are sent to the game . With the countdown everyone move towards the weapon but ")
              #input statement for the user to decide where the story gets 
    act = input(prompt="What you should do A)run far away B) run towards the weapon : \n")
    act = act.casefold()
              #if the input is a we move to the scene_5
    if act =='a' or act == 'A'or act =='run far away ' :
        print("""You ran away far away from the ground and hid yourself and while 
              running you heeard the names of the people that were killed in the fight """)
        scene_5()
     #if input is b we get killed 
    elif act =='b' or act == 'B' or act == 'run toward':
        print("""you got killed in the fight of choosing weapons """)
        fail()
    # if the input is just run we need the user to specify to which direction so we start from the beggining
    elif act =='run':
        print("please specify to where ")
        scene_4()
    #if there is no input or the input cannot be known or matches this ststement works and we need to start from the begining of the scene  
    else:
        print("Please follow the hint ")
        scene_4()
              
              
              
 #scene 5 is described it works when user moves from 4 scene 
def scene_5():
    #for making a dividion between the codes
    print("====================================================================")
    #description of what s happening 
    print("""Most of the tributes got killed. Only you Peter and another contestant are left .You see a 
          bow and arrow""")
    # pause
    time.sleep(1)
    #input from the user from where the story moves forward
    #this is the last scene which will define whether you are a winner or looser
    choose= input(prompt="Do you want the weapon please type yes or no \n")
    choose = choose.casefold()
    #if ans is yes the use is the winner and further we ask whether they want to play again using input()
    if choose =='yes' or choose =='y' or choose =='YES' or choose =='Yes' or choose =='a' or choose =='A':
        print("""You killed the last tributer and saved peter and became the winner . Congrats you win """)
        print("\U0001F37E"*10)
        
        restart=input(prompt="Do you want to play again Hint : Type yes or no")
        restart = restart.casefold()
        #if yes is inputted by user the game. starts again
        if restart == 'yes' or restart =='Y'or restart == 'y' or restart=='YES' :
            print("welecome again")
            scene_1()
                
                
        elif restart == 'no' or restart =='n' or restart=='NO' or restart =='N':
            print("Thanks for Playing")
                
                
        else:
            print("please follow the hint Hint : only enter Yes or No")
            Scene_5()
                
            
        
            
            
    #if no is choosen the game ends
    elif choose =='no' or choose=='n':
        print(" You and peter get killed")
        print("\U0001F480")
        fail()
    #if you choose wrong option you get to restart the code 
    else:
        print("please enter again following the hint")
        scene_5()
              
              
#this function is comes when the user does not win the game by choosing options that lead to failure    
def fail():
    print("======================================================================")
    print("\U0001F636" * 5)
    print("You've failed, but thanks for playing!")
    input('<Press any key to exit>\n')


scene_1()
# Out:
# Welcome to The Hunger Games
# 🏹🏹🏹🏹🏹
# You live in a world where most of the part of the earth is submerged under water ,
#      the only habitable place in the world is North America .It has been divided
#     into 12 Districts and each year an event is organised by the dictator in the Capitol of the country named
#     as The Hunger Games . It is done as a punishmenmt of the roits which happened a few years back .
#     For this game the contestant that are choosen are of age between 12 to 16 and they are called tributes
#     and from each district two person are choose one of female and male .They are choosen by a
#     lottery system .
# Let the Game Begin
# 3
# 2
# 1
# 0
# What is your name :
# p
# Welcome p but here in the new  world you will be known as p Everdeen .
#
# Do you want to start the game . Hint : Type Yes or No
# n
# You need courage to start
# 💪
# ...
# 😶😶😶😶😶
# You've failed, but thanks for playing!
# <Press any key to exit>
